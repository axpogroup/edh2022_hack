# %%
import pandas as pd
import numpy as np
import json

# %%
df_gbr = pd.read_csv("../output.csv")
df_gbr
# Out:
#           egid  gkat   gklas                  street   zip        city  \
# 0       199688  1020  1122.0   Franz-Zelgerstrasse 9  6023  Rothenburg
# 1       200332  1040     NaN         Buzibachring 10  6023  Rothenburg
# 2    190902574  1020  1122.0          Krauerhusweg 2  6206  Neuenkirch
# 3       223372  1020  1110.0     Windblosenstrasse 6  6206  Neuenkirch
# 4      2384180  1020  1110.0            Bachtalen 33  6020       Emmen
# ..         ...   ...     ...                     ...   ...         ...
# 196  502292722  1060  1242.0          Sonnhalde 3c.2  6206  Neuenkirch
# 197     199978  1020  1110.0           Pilatusring 6  6023  Rothenburg
# 198  191506001  1060  1274.0      Krauerhusstrasse 3  6206  Neuenkirch
# 199     199641  1020  1110.0     Hermolingenhalde 12  6023  Rothenburg
# 200     199697  1020  1121.0  Franz-Zelgerstrasse 27  6023  Rothenburg
#
#                   description    building_type  coordinate_lat  \
# 0                         NaN      RESIDENTIAL     2663131.507
# 1                         NaN      RESIDENTIAL     2661926.186
# 2                         NaN      RESIDENTIAL     2657840.080
# 3                         NaN      RESIDENTIAL     2657904.800
# 4                         NaN      RESIDENTIAL     2663056.995
# ..                        ...              ...             ...
# 196                    Garage  NON_RESIDENTIAL     2659226.973
# 197                       NaN      RESIDENTIAL     2663361.562
# 198  Telefonzentrale Swisscom  NON_RESIDENTIAL     2657871.699
# 199                       NaN      RESIDENTIAL     2662680.450
# 200                       NaN      RESIDENTIAL     2662918.746
#
#      coordinate_lon   area  volume  \
# 0       1216293.040  191.0     NaN
# 1       1215903.060  931.0     NaN
# 2       1217285.315  310.0     NaN
# 3       1216664.959  142.0     NaN
# 4       1215653.632  118.0     NaN
# ..              ...    ...     ...
# 196     1216586.425   21.0     NaN
# 197     1216682.335   95.0     NaN
# 198     1217166.782  287.0     NaN
# 199     1216289.989  119.0     NaN
# 200     1216419.723  172.0     NaN
#
#                                                    url
# 0    https://map.geo.admin.ch/?ch.bfs.gebaeude_wohn...
# 1    https://map.geo.admin.ch/?ch.bfs.gebaeude_wohn...
# 2    https://map.geo.admin.ch/?ch.bfs.gebaeude_wohn...
# 3    https://map.geo.admin.ch/?ch.bfs.gebaeude_wohn...
# 4    https://map.geo.admin.ch/?ch.bfs.gebaeude_wohn...
# ..                                                 ...
# 196  https://map.geo.admin.ch/?ch.bfs.gebaeude_wohn...
# 197  https://map.geo.admin.ch/?ch.bfs.gebaeude_wohn...
# 198  https://map.geo.admin.ch/?ch.bfs.gebaeude_wohn...
# 199  https://map.geo.admin.ch/?ch.bfs.gebaeude_wohn...
# 200  https://map.geo.admin.ch/?ch.bfs.gebaeude_wohn...
#
# [201 rows x 13 columns]

# %%
df_gxf = pd.read_csv("../dxf/volume_and_locations.csv", converters={
    "ground_center": json.loads,
    "bounding_box": json.loads
})
df_gxf
# Out:
#       Unnamed: 0       volume  \
# 0              0  2338.007465
# 1              1   403.423894
# 2              2  1112.016909
# 3              3  1489.510729
# 4              4  1330.313159
# ...          ...          ...
# 1874        1874    51.643006
# 1875        1875  1342.356150
# 1876        1876  1592.914983
# 1877        1877  1576.295733
# 1878        1878  1448.997093
#
#                                            bounding_box  \
# 0     [[2657457.662999999, 1216397.927999999, 616.06...
# 1     [[2658155.833000001, 1216799.57, 542.455000000...
# 2     [[2657472.517999999, 1216821.289000001, 582.62...
# 3     [[2658703.905000001, 1216292.114, 546.93899999...
# 4     [[2657652.613000002, 1217280.982999999, 545.34...
# ...                                                 ...
# 1874  [[2657492.813000001, 1217347.510000002, 551.92...
# 1875  [[2658564.399999999, 1216366.669, 542.32899999...
# 1876  [[2657573.408, 1217398.465, 539.4590000000026]...
# 1877  [[2655775.559999999, 1215411.103, 785.62099999...
# 1878  [[2659366.557999998, 1216495.109000001, 531.88...
#
#                                           ground_center                Layer  \
# 0     [2657467.5764999986, 1216407.845999999, 616.06...  Gebaeude Einzelhaus
# 1     [2658159.8820000016, 1216804.7880000006, 542.4...  Gebaeude Einzelhaus
# 2        [2657480.534, 1216829.3585, 582.6230000000069]  Gebaeude Einzelhaus
# 3     [2658711.1400000006, 1216299.5539999995, 546.9...  Gebaeude Einzelhaus
# 4     [2657658.561000001, 1217288.171, 545.347999999...  Gebaeude Einzelhaus
# ...                                                 ...                  ...
# 1874  [2657494.2705000006, 1217348.9275000007, 551.9...  Gebaeude Einzelhaus
# 1875  [2658572.692, 1216374.9415000011, 542.32899999...  Gebaeude Einzelhaus
# 1876  [2657586.6889999993, 1217406.1555000006, 539.4...  Gebaeude Einzelhaus
# 1877  [2655781.8204999994, 1215419.1779999994, 785.6...  Gebaeude Einzelhaus
# 1878  [2659374.4589999984, 1216503.0085000005, 531.8...  Gebaeude Einzelhaus
#
#      EntityHandle
# 0              70
# 1              DE
# 2             10A
# 3             160
# 4             1D3
# ...           ...
# 1874        237B4
# 1875        237C6
# 1876        237F8
# 1877        238E4
# 1878        2391A
#
# [1879 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure



fig = figure(figsize=(16, 6), dpi=80)
xs = [p[0] for p in df_gxf.ground_center]
ys = [p[1] for p in df_gxf.ground_center]
plt.scatter(xs, ys, s=.5, marker='o', c='green')

xs = df_gbr.coordinate_lat
ys = df_gbr.coordinate_lon
plt.scatter(xs, ys, s=1, marker='x', c='red')

plt.show()
#plt.savefig("fig.svg", dpi=3000, format='svg')
